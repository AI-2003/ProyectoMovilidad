# %%
import pandas as pd
import geopandas as gpd
from tqdm import tqdm
from Functions.prepping import *
from Functions.points import clean_gps_data, classify_route_variant
from Functions.maps import comparing_map
from scipy.stats import percentileofscore

# ================================================================
# Paths to files and initial values
# Change these to fit your needs
# ================================================================
file_path = "Data/ruta5.csv"
ruta_5_json_path = "Data/ruta_5.json"
map_path = 'Maps/comparing_map.html'
branches_path = "Data/branches_df.geojson"
route = 'RUTA 5'
rounding_precision = 4
closer_threshold = 3
time_diff_threshold = 120
predictions_path = "Data/predictions_df.csv"


# ================================================================
# Get necessary data
# ================================================================

# Get data
df = pd.read_csv(file_path)
# Format and filter to this file needs
empiric_df = format_df(df)
empiric_df = empiric_df[empiric_df['Route'] == route]
empiric_df
# Out:
#                      Time  Plate   Route   Latitude  Longitude  velocidad  \
# 0     2023-02-27 00:00:06  50050  RUTA 5  19.385832 -99.226166          0
# 1     2023-02-27 00:00:43  50116  RUTA 5  19.385124 -99.198440          0
# 2     2023-02-27 00:00:45  50050  RUTA 5  19.385832 -99.226166          0
# 3     2023-02-27 00:01:44  50050  RUTA 5  19.385832 -99.226166          0
# 4     2023-02-27 00:01:50  50116  RUTA 5  19.385122 -99.198440          0
# ...                   ...    ...     ...        ...        ...        ...
# 74709 2023-03-05 23:59:39  50336  RUTA 5  19.342667 -99.279760          0
# 74710 2023-03-05 23:59:39  50162  RUTA 5  19.342611 -99.287440          0
# 74711 2023-03-05 23:59:40  50242  RUTA 5  19.380463 -99.250160          0
# 74712 2023-03-05 23:59:47  50116  RUTA 5  19.385002 -99.198310          0
# 74713 2023-03-05 23:59:59  50173  RUTA 5  19.382156 -99.239060         11
#
#        contadorpasajeros                                    tipounidad  Scale
# 0                      0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# 1                      0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# 2                      0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# 3                      0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# 4                      0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# ...                  ...                                           ...    ...
# 74709                  0                                      VAGONETA      2
# 74710                  0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# 74711                  0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# 74712                  0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
# 74713                  0  AUTOBUS CORTO (ENTRE 7.5 Y 10 M DE LONGITUD)      2
#
# [74714 rows x 9 columns]

# %%
branches_df = gpd.read_file("Data/branches_df.geojson", driver="GeoJSON")
predictions_df = pd.read_csv("Data/predictions_df.csv")
predictions_df
# Out:
#      Plate        Date  Deviation  Predicted_Branch
# 0    50050  2023-02-27   0.001195                 5
# 1    50050  2023-02-28   0.000594                 5
# 2    50050  2023-03-01   0.000523                 1
# 3    50050  2023-03-02   0.000852                 3
# 4    50050  2023-03-03   0.000860                 1
# ..     ...         ...        ...               ...
# 137  50112  2023-03-03   0.000830                 5
# 138  50112  2023-03-04   0.000643                 3
# 139  50112  2023-03-05   0.003987                13
# 140  50214  2023-03-04   0.000097                 1
# 141  50254  2023-03-05   0.012458                 4
#
# [142 rows x 4 columns]

# %%
import folium

# %%
# Iterate over each unique plate
for plate in empiric_df['Plate'].unique()[9:10]:
    plate_df = empiric_df[empiric_df['Plate'] == plate]
    sorted_dates = sorted(plate_df['Time'].dt.date.unique())
    # Iterate over each unique date for the current plate
    for day in sorted_dates[:1]:
        plate_date_df = plate_df[plate_df['Time'].dt.date == day]
        clean_df = clean_gps_data(plate_date_df, rounding_precision, time_diff_threshold, closer_threshold)
        prediction = predictions_df[(predictions_df["Plate"] == plate) & (predictions_df["Date"] == str(day))].iloc[0]
        deviation = prediction["Deviation"]
        predicted_branch = prediction["Predicted_Branch"]
        branch_df = branches_df[branches_df["Branch"] == str(predicted_branch)].iloc[0]
        percentile = percentileofscore(predictions_df["Deviation"], deviation)
        print(f'The bus with plate {plate} on the day {day} was on the {percentile}% percentile') # Bigger is worst
        # Map
        m = comparing_map(clean_df, branch_df, "Maps/trash.html", f'Placa: {plate}. Día: {day}. Variante predicha: {predicted_branch}. Discrepancia: {deviation}. Percentil de la discrepancia: {round(percentile,2)}')
m
# Out:
# The bus with plate 50234 on the day 2023-02-27 was on the 28.169014084507044% percentile
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffd896b696bd54a06b3d9d243dcafa09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 top: 10px; left: 50px;
#                 background-color: white; z-index:9999; font-size:15px;
#                 border:2px solid grey; padding: 10px;&quot;&gt;
#         &lt;b&gt;Placa: 50234. Día: 2023-02-27. Variante predicha: 13. Discrepancia: 0.0006638881504557. Percentil de la discrepancia: 28.17%&lt;/b&gt;
#     &lt;/div&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 bottom: 50px; left: 50px;
#                 background-color: white; z-index:9999; font-size:14px;
#                 border:2px solid grey; padding: 10px;&quot;&gt;
#         &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt; Nodos de la variante predicha&lt;br&gt;
#         &lt;i class=&quot;fa fa-circle&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt; Registros GPS (filtrados)&lt;br&gt;
#         &lt;i class=&quot;fa fa-minus&quot; style=&quot;color:green&quot;&gt;&lt;/i&gt; Conexión entre datos GPS y punto más cercano de la variante predicha
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffd896b696bd54a06b3d9d243dcafa09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffd896b696bd54a06b3d9d243dcafa09 = L.map(
#                 &quot;map_ffd896b696bd54a06b3d9d243dcafa09&quot;,
#                 {
#                     center: [19.378727, -99.24534],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40e2b31d6a4479410dd5b8bff6578469 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_40e2b31d6a4479410dd5b8bff6578469.addTo(map_ffd896b696bd54a06b3d9d243dcafa09);
#
#
#             var poly_line_03e250cb361be566b512470e0117be44 = L.polyline(
#                 [[19.378727, -99.24534], [19.379626, -99.2454958]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffd896b696bd54a06b3d9d243dcafa09);
#
#
#             var poly_line_d41a95531851feda5cabac5ae6fb35b9 = L.polyline(
#                 [[19.378874, -99.24532], [19.379626, -99.2454958]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffd896b696bd54a06b3d9d243dcafa09);
#
#
#             var poly_line_7d60137a3491e0dd0865a098d7e59226 = L.polyline(
#                 [[19.37898, -99.245255], [19.379626, -99.2454958]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffd896b696bd54a06b3d9d243dcafa09);
#
#
#             var poly_line_3a181110edd42de6b68d8b064ff0dc59 = L.polyline(
#                 [[19.380514, -99.24715], [19.3791676, -99.2466057]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ffd896b696bd54a06b3d9d243dcafa09);
#
#
#             var poly_line_3ff8e8f3b244bc6bd675f312d67e93d8 = L.polyline(
#                 [[19.380604, -99.24933], [19.3783784, -99.2488546]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;
